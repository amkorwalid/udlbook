# %% [markdown]
# <a href="https://colab.research.google.com/github/amkorwalid/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jqd8wlul
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jqd8wlul
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(1, 15, 3, stride=2, padding='valid'),
nn.ReLU(),
nn.Conv1d(15, 15, 3, stride=2, padding='valid'),
nn.ReLU(),
nn.Conv1d(15, 15, 3, stride=2, padding='valid'),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.119413, train error 77.85,  val loss 2.125437, percent error 78.80
# Epoch     1, train loss 1.563091, train error 61.40,  val loss 1.577831, percent error 63.30
# Epoch     2, train loss 1.348597, train error 52.92,  val loss 1.368656, percent error 54.10
# Epoch     3, train loss 1.276270, train error 52.58,  val loss 1.283469, percent error 53.30
# Epoch     4, train loss 1.136193, train error 43.72,  val loss 1.157265, percent error 48.40
# Epoch     5, train loss 1.103953, train error 44.12,  val loss 1.122515, percent error 45.70
# Epoch     6, train loss 1.026327, train error 40.70,  val loss 1.091811, percent error 43.10
# Epoch     7, train loss 1.141248, train error 41.95,  val loss 1.202581, percent error 45.00
# Epoch     8, train loss 0.824185, train error 34.32,  val loss 0.857969, percent error 35.30
# Epoch     9, train loss 0.755333, train error 30.40,  val loss 0.787714, percent error 33.00
# Epoch    10, train loss 0.650711, train error 25.93,  val loss 0.694391, percent error 28.90
# Epoch    11, train loss 0.639851, train error 24.05,  val loss 0.713552, percent error 26.20
# Epoch    12, train loss 0.634421, train error 23.60,  val loss 0.722626, percent error 27.10
# Epoch    13, train loss 0.465205, train error 18.05,  val loss 0.510409, percent error 19.70
# Epoch    14, train loss 0.377734, train error 14.35,  val loss 0.446807, percent error 15.80
# Epoch    15, train loss 0.390118, train error 14.85,  val loss 0.491033, percent error 17.50
# Epoch    16, train loss 0.329128, train error 12.12,  val loss 0.443270, percent error 15.40
# Epoch    17, train loss 0.296162, train error 10.60,  val loss 0.404164, percent error 13.90
# Epoch    18, train loss 0.239567, train error 8.65,  val loss 0.343534, percent error 10.80
# Epoch    19, train loss 0.370201, train error 13.35,  val loss 0.502745, percent error 16.60
# Epoch    20, train loss 0.193810, train error 6.82,  val loss 0.337205, percent error 10.20
# Epoch    21, train loss 0.180643, train error 5.78,  val loss 0.336600, percent error 11.00
# Epoch    22, train loss 0.150764, train error 4.78,  val loss 0.283111, percent error 8.70
# Epoch    23, train loss 0.138255, train error 4.18,  val loss 0.289795, percent error 8.30
# Epoch    24, train loss 0.205444, train error 8.18,  val loss 0.366281, percent error 11.80
# Epoch    25, train loss 0.156414, train error 5.68,  val loss 0.332550, percent error 9.50
# Epoch    26, train loss 0.152980, train error 4.95,  val loss 0.349789, percent error 10.40
# Epoch    27, train loss 0.124673, train error 4.22,  val loss 0.286543, percent error 8.20
# Epoch    28, train loss 0.111411, train error 3.45,  val loss 0.293032, percent error 8.80
# Epoch    29, train loss 0.118436, train error 3.97,  val loss 0.294643, percent error 8.40
# Epoch    30, train loss 0.153052, train error 5.68,  val loss 0.355947, percent error 10.30
# Epoch    31, train loss 0.108207, train error 3.43,  val loss 0.278538, percent error 8.70
# Epoch    32, train loss 0.127947, train error 4.50,  val loss 0.329027, percent error 9.00
# Epoch    33, train loss 0.101172, train error 3.38,  val loss 0.311013, percent error 9.20
# Epoch    34, train loss 0.115726, train error 4.15,  val loss 0.346330, percent error 10.00
# Epoch    35, train loss 0.104038, train error 3.22,  val loss 0.306828, percent error 8.70
# Epoch    36, train loss 0.093258, train error 2.93,  val loss 0.316428, percent error 8.50
# Epoch    37, train loss 0.086265, train error 2.38,  val loss 0.293444, percent error 8.60
# Epoch    38, train loss 0.077506, train error 2.30,  val loss 0.290099, percent error 7.30
# Epoch    39, train loss 0.098545, train error 3.12,  val loss 0.314051, percent error 8.30
# Epoch    40, train loss 0.065754, train error 1.85,  val loss 0.294131, percent error 7.90
# Epoch    41, train loss 0.062641, train error 1.32,  val loss 0.294040, percent error 8.50
# Epoch    42, train loss 0.063080, train error 1.57,  val loss 0.301596, percent error 8.30
# Epoch    43, train loss 0.058851, train error 1.43,  val loss 0.297163, percent error 8.20
# Epoch    44, train loss 0.059261, train error 1.68,  val loss 0.307506, percent error 7.90
# Epoch    45, train loss 0.056229, train error 1.43,  val loss 0.311953, percent error 8.10
# Epoch    46, train loss 0.055447, train error 1.05,  val loss 0.305661, percent error 8.50
# Epoch    47, train loss 0.052063, train error 1.03,  val loss 0.300380, percent error 8.00
# Epoch    48, train loss 0.051941, train error 0.97,  val loss 0.317548, percent error 8.20
# Epoch    49, train loss 0.054621, train error 1.35,  val loss 0.315478, percent error 8.70
# Epoch    50, train loss 0.047004, train error 1.03,  val loss 0.325192, percent error 8.70
# Epoch    51, train loss 0.046717, train error 0.88,  val loss 0.321031, percent error 8.50
# Epoch    52, train loss 0.048755, train error 1.07,  val loss 0.325580, percent error 8.20
# Epoch    53, train loss 0.049079, train error 1.15,  val loss 0.329628, percent error 7.70
# Epoch    54, train loss 0.051007, train error 1.22,  val loss 0.340344, percent error 9.10
# Epoch    55, train loss 0.046122, train error 0.93,  val loss 0.343101, percent error 8.90
# Epoch    56, train loss 0.048307, train error 1.20,  val loss 0.338774, percent error 8.70
# Epoch    57, train loss 0.049554, train error 1.07,  val loss 0.347111, percent error 8.80
# Epoch    58, train loss 0.044747, train error 1.03,  val loss 0.335007, percent error 8.00
# Epoch    59, train loss 0.040741, train error 0.82,  val loss 0.353936, percent error 8.40
# Epoch    60, train loss 0.036783, train error 0.65,  val loss 0.336554, percent error 7.90
# Epoch    61, train loss 0.035718, train error 0.60,  val loss 0.339133, percent error 8.50
# Epoch    62, train loss 0.039152, train error 0.70,  val loss 0.348326, percent error 8.00
# Epoch    63, train loss 0.035629, train error 0.55,  val loss 0.343771, percent error 8.40
# Epoch    64, train loss 0.034601, train error 0.57,  val loss 0.342822, percent error 8.40
# Epoch    65, train loss 0.034379, train error 0.57,  val loss 0.350581, percent error 8.50
# Epoch    66, train loss 0.034354, train error 0.53,  val loss 0.351070, percent error 8.70
# Epoch    67, train loss 0.036096, train error 0.70,  val loss 0.350141, percent error 8.50
# Epoch    68, train loss 0.035123, train error 0.62,  val loss 0.356581, percent error 8.60
# Epoch    69, train loss 0.033632, train error 0.68,  val loss 0.353100, percent error 8.80
# Epoch    70, train loss 0.032130, train error 0.45,  val loss 0.359155, percent error 8.70
# Epoch    71, train loss 0.032624, train error 0.50,  val loss 0.356585, percent error 8.40
# Epoch    72, train loss 0.032249, train error 0.50,  val loss 0.353503, percent error 8.50
# Epoch    73, train loss 0.032044, train error 0.47,  val loss 0.353640, percent error 8.50
# Epoch    74, train loss 0.031122, train error 0.50,  val loss 0.363148, percent error 8.60
# Epoch    75, train loss 0.031067, train error 0.45,  val loss 0.364364, percent error 8.70
# Epoch    76, train loss 0.029885, train error 0.47,  val loss 0.360139, percent error 8.60
# Epoch    77, train loss 0.032081, train error 0.45,  val loss 0.369551, percent error 8.40
# Epoch    78, train loss 0.029662, train error 0.38,  val loss 0.368908, percent error 8.70
# Epoch    79, train loss 0.030426, train error 0.43,  val loss 0.373306, percent error 8.60
# Epoch    80, train loss 0.028997, train error 0.40,  val loss 0.370367, percent error 8.80
# Epoch    81, train loss 0.028226, train error 0.40,  val loss 0.370990, percent error 8.70
# Epoch    82, train loss 0.028114, train error 0.32,  val loss 0.370130, percent error 8.60
# Epoch    83, train loss 0.028129, train error 0.32,  val loss 0.370521, percent error 8.80
# Epoch    84, train loss 0.028506, train error 0.38,  val loss 0.372337, percent error 8.60
# Epoch    85, train loss 0.027802, train error 0.40,  val loss 0.374882, percent error 8.40
# Epoch    86, train loss 0.027436, train error 0.40,  val loss 0.372770, percent error 8.70
# Epoch    87, train loss 0.027396, train error 0.38,  val loss 0.372444, percent error 8.70
# Epoch    88, train loss 0.027578, train error 0.38,  val loss 0.374421, percent error 8.40
# Epoch    89, train loss 0.027065, train error 0.30,  val loss 0.377208, percent error 8.80
# Epoch    90, train loss 0.026865, train error 0.30,  val loss 0.378769, percent error 8.60
# Epoch    91, train loss 0.026721, train error 0.30,  val loss 0.375682, percent error 8.70
# Epoch    92, train loss 0.026574, train error 0.25,  val loss 0.378557, percent error 8.60
# Epoch    93, train loss 0.026853, train error 0.32,  val loss 0.381869, percent error 8.50
# Epoch    94, train loss 0.026346, train error 0.30,  val loss 0.379454, percent error 8.60
# Epoch    95, train loss 0.026526, train error 0.25,  val loss 0.380894, percent error 8.70
# Epoch    96, train loss 0.025906, train error 0.25,  val loss 0.384223, percent error 8.80
# Epoch    97, train loss 0.026619, train error 0.38,  val loss 0.383743, percent error 9.00
# Epoch    98, train loss 0.026485, train error 0.38,  val loss 0.386229, percent error 8.50
# Epoch    99, train loss 0.026118, train error 0.30,  val loss 0.386503, percent error 8.70
